# %%
import subprocess
import time
import random
import pandas as pd

# %% [markdown]
# ## Evaluating One Candidate

# %%
def apply_passes(input, pass_order):
    cmd = ["./compile.sh", input]
    # print(cmd)
    # cmd += input
    cmd += pass_order
    # print(" ".join(cmd))

    result = subprocess.run(cmd, capture_output=True, text=True, check=True, cwd="./beebs")
    return result

def _measure_runtime(binary, count=50, mode="cycles"):
    total_score = 0.0
    base_score = 0.0
    for _ in range(count):
        # start = time.time()
        result = subprocess.run(
            ["perf", "stat", "-e", "cycles", f"./{binary}/{binary}"],
            capture_output=True,
            text=True,
            cwd="./beebs/src"
        )
        
        lines = result.stderr.splitlines()
        cycles_line = next((line for line in lines if "cycles" in line), None)
        time_line = next((line for line in lines if "seconds time elapsed" in line), None)

        result_base = subprocess.run(
            ["perf", "stat", "-e", "cycles", f"./{binary}/{binary}_base"],
            capture_output=True,
            text=True,
            cwd="./beebs/src"
        )
        # Extract cycles and time from stderr
        lines_base = result_base.stderr.splitlines()
        cycles_line_base = next((line for line in lines_base if "cycles" in line), None)
        time_line_base = next((line for line in lines_base if "seconds time elapsed" in line), None)

        if cycles_line and time_line and cycles_line_base and time_line_base:
            cycles = int(cycles_line.split()[0].replace(",", ""))
            cycles_base = int(cycles_line_base.split()[0].replace(",", ""))

            elapsed_time = float(time_line.split()[0])
            elapsed_time_base = float(time_line_base.split()[0])

            if mode == "time":
                # Use elapsed time directly
                total_score += elapsed_time
                base_score += elapsed_time_base
            elif mode == "cycles":
                # Use cycles as the score
                total_score += cycles
                base_score += cycles_base
    return (total_score - base_score) / count

def measure_runtime_alt(binary, count=10, mode="cycles"):
    total_score = 0.0
    for _ in range(count):
        # start = time.time()
        result = subprocess.run(
            ["perf", "stat", "-e", "cycles", f"./{binary}/{binary}"],
            capture_output=True,
            text=True,
            cwd="./beebs/src"
        )
        
        lines = result.stderr.splitlines()
        cycles_line = next((line for line in lines if "cycles" in line), None)
        time_line = next((line for line in lines if "seconds time elapsed" in line), None)

        if cycles_line and time_line:
            cycles = int(cycles_line.split()[0].replace(",", ""))

            elapsed_time = float(time_line.split()[0])

            if mode == "time":
                # Use elapsed time directly
                total_score += elapsed_time
            elif mode == "cycles":
                # Use cycles as the score
                total_score += cycles
    return (total_score) / count

def measure_runtime(binary, count=10, mode="cycles"):
    total_score = 0.0
    total_base = 0.0
    for _ in range(count):
        # start = time.time()
        result = subprocess.run(
            [f"./{binary}/{binary}"],
            capture_output=True,
            text=True,
            cwd="./beebs/src"
        )

        result2 = subprocess.run(
            [f"./{binary}/{binary}_base"],
            capture_output=True,
            text=True,
            cwd="./beebs/src"
        )

        if "Cycles" in result.stdout:
            cycles = int(result.stdout.split("Cycles:")[1].split()[0])
            base = int(result2.stdout.split("Cycles:")[1].split()[0])
            if mode == "cycles":
                total_score += cycles
                total_base += base
    return (total_score - total_base) / count

def measure_size(binary):
    result = subprocess.run(["size", binary], capture_output=True, text=True)
    lines = result.stdout.strip().split("\n")
    if len(lines) < 2:
        return None
    size_fields = lines[1].split()
    total_size = sum(int(x) for x in size_fields[:4])
    return total_size

def evaluate_candidate(pass_order, input, workdir, mode="runtime"):
    candidate = f"{workdir}/candidate_bin"
    try:
        apply_passes(input, pass_order)
        if mode == "runtime":
            fitness = measure_runtime(input)
        elif mode == "size":
            fitness = measure_size(input)
        else:
            raise ValueError("Invalid mode")
        return fitness
    except subprocess.CalledProcessError:
        return float("inf")  # Penalize failure

# %%
measure_runtime("crc32", 1)

# %%
apply_passes("dijkstra", ["-O2", "-funroll-loops"])
# Out:
# CompletedProcess(args=['./compile.sh', 'dijkstra', '-O2', '-funroll-loops'], returncode=0, stdout='rm -rf .libs _libs\ntest -z "libdummycrt0.la libsupport.la libdummygcc.la libdummyc.la libdummym.la" || rm -f libdummycrt0.la libsupport.la libdummygcc.la libdummyc.la libdummym.la\nrm -f ./so_locations\nrm -f *.o\nrm -f *.lo\n  CC       dummy-crt0.lo\n  CCLD     libdummycrt0.la\n  CC       libsupport_la-main.lo\n  CC       libsupport_la-board.lo\n  CC       libsupport_la-chip.lo\n  CCLD     libsupport.la\n  CC       dummy-libgcc.lo\n  CCLD     libdummygcc.la\n  CC       dummy-libc.lo\n  CCLD     libdummyc.la\n  CC       dummy-libm.lo\n  CCLD     libdummym.la\n rm -f dijkstra\nrm -rf .libs _libs\ntest -z "libdijkstra.la" || rm -f libdijkstra.la\nrm -f ./so_locations\nrm -f *.o\nrm -f *.lo\n  CC       dijkstra_small.lo\n  CCLD     libdijkstra.la\n  CCLD     dijkstra\n', stderr='main.c: In function \'main\':\nmain.c:61:5: warning: implicit declaration of function \'printf\' [-Wimplicit-function-declaration]\n   61 |     printf("Cycles: %lu\\n", cycles_after - cycles_before);\n      |     ^~~~~~\nmain.c:61:5: warning: incompatible implicit declaration of built-in function \'printf\'\nmain.c:27:1: note: include \'<stdio.h>\' or provide a declaration of \'printf\'\n   26 | #include "support.h"\n  +++ |+#include <stdio.h>\n   27 | \ndummy-libc.c:55:1: warning: conflicting types for built-in function \'memcpy\'; expected \'void *(void *, const void *, long unsigned int)\' [-Wbuiltin-declaration-mismatch]\n   55 | memcpy (void *dest __attribute__ ((unused)),\n      | ^~~~~~\ndummy-libc.c:30:1: note: \'memcpy\' is declared in header \'<string.h>\'\n   29 | #include <stdio.h>\n  +++ |+#include <string.h>\n   30 | \ndummy-libc.c:64:1: warning: conflicting types for built-in function \'memmove\'; expected \'void *(void *, const void *, long unsigned int)\' [-Wbuiltin-declaration-mismatch]\n   64 | memmove (void *dest __attribute__ ((unused)),\n      | ^~~~~~~\ndummy-libc.c:64:1: note: \'memmove\' is declared in header \'<string.h>\'\ndummy-libc.c:73:1: warning: conflicting types for built-in function \'memset\'; expected \'void *(void *, int,  long unsigned int)\' [-Wbuiltin-declaration-mismatch]\n   73 | memset (void *s __attribute__ ((unused)),\n      | ^~~~~~\ndummy-libc.c:73:1: note: \'memset\' is declared in header \'<string.h>\'\ndummy-libc.c:81:1: warning: conflicting types for built-in function \'memcmp\'; expected \'int(const void *, const void *, long unsigned int)\' [-Wbuiltin-declaration-mismatch]\n   81 | memcmp (const void *s1 __attribute__ ((unused)),\n      | ^~~~~~\ndummy-libc.c:81:1: note: \'memcmp\' is declared in header \'<string.h>\'\ndummy-libc.c:103:1: warning: conflicting types for built-in function \'calloc\'; expected \'void *(long unsigned int,  long unsigned int)\' [-Wbuiltin-declaration-mismatch]\n  103 | calloc (unsigned int nmemb __attribute__ ((unused)),\n      | ^~~~~~\ndummy-libc.c:30:1: note: \'calloc\' is declared in header \'<stdlib.h>\'\n   29 | #include <stdio.h>\n  +++ |+#include <stdlib.h>\n   30 | \ndummy-libc.c:111:1: warning: conflicting types for built-in function \'malloc\'; expected \'void *(long unsigned int)\' [-Wbuiltin-declaration-mismatch]\n  111 | malloc (unsigned int size __attribute__ ((unused)) )\n      | ^~~~~~\ndummy-libc.c:111:1: note: \'malloc\' is declared in header \'<stdlib.h>\'\ndummy-libc.c:134:1: warning: conflicting types for built-in function \'strlen\'; expected \'long unsigned int(const char *)\' [-Wbuiltin-declaration-mismatch]\n  134 | strlen (const char *s __attribute__ ((unused)) )\n      | ^~~~~~\ndummy-libc.c:134:1: note: \'strlen\' is declared in header \'<string.h>\'\n')

# %% [markdown]
# ## Genetic Algorithm Operators

# %%
def random_candidate(pass_pool, max_len=5):
    # length = random.randint(1, max_len)
    return random.sample(pass_pool, max_len)



def crossover(parent1, parent2, max_len=5):
    # Pick cut points
    p1_cut = random.randint(1, len(parent1))
    p2_cut = random.randint(1, len(parent2))

    # Combine slices
    child = parent1[:p1_cut] + parent2[p2_cut:]

    # Remove duplicates while preserving order
    seen = set()
    deduped_child = []
    for p in child:
        if p not in seen:
            deduped_child.append(p)
            seen.add(p)

    # Clip to max length
    return deduped_child[:max_len]


def mutate(candidate, pass_pool, mutation_rate=0.1, max_len=5):
    # Start with a copy
    mutated = candidate[:]
    
    # Replace one random pass in the candidate
    if mutated and random.random() < mutation_rate:
        replace_idx = random.randint(0, len(mutated) - 1)
        available = list(set(pass_pool) - set(mutated))
        if available:
            mutated[replace_idx] = random.choice(available)

    # Random insertion
    if len(mutated) < max_len and random.random() < mutation_rate:
        available = list(set(pass_pool) - set(mutated))
        if available:
            insert_pos = random.randint(0, len(mutated))
            mutated.insert(insert_pos, random.choice(available))

    # Random deletion
    if len(mutated) > 1 and random.random() < mutation_rate:
        del_pos = random.randint(0, len(mutated) - 1)
        mutated.pop(del_pos)

    return mutated

# %% [markdown]
# ## Running the GA loop

# %%
def run_ga(input_bc, pass_pool, generations=10, pop_size=20, seq_length=5):
    population = [random_candidate(pass_pool, seq_length) for _ in range(pop_size)]
    stats = []

    apply_passes(input_bc, [])
    subprocess.run(["mv", f"{input_bc}/{input_bc}", f"{input_bc}/{input_bc}_base"], cwd= "./beebs/src", capture_output=True, text=True, check=True)

    # Initialize global best candidate
    global_best_candidate = None
    global_best_fitness = float("inf")

    for generation in range(generations):
        print(f"Generation {generation}")
        fitnesses = []
        for candidate in population:
            fitness = evaluate_candidate(candidate, input_bc, "./scratch")
            fitnesses.append((fitness, candidate))
            # print(f"Candidate {candidate} => Fitness {fitness}")

        # Update global best candidate
        for fitness, candidate in fitnesses:
            if fitness < global_best_fitness:
                global_best_fitness = fitness
                global_best_candidate = candidate

        # Selection
        fitnesses.sort(key=lambda x: x[0])
        population = [cand for _, cand in fitnesses[:(pop_size // 2)]]

        # Crossover and mutation
        new_population = []
        while len(new_population) < pop_size:
            parents = random.sample(population, 2)
            c1 = crossover(parents[0], parents[1], seq_length)
            c1 = mutate(c1, pass_pool, seq_length)
            new_population.append(c1)

        population = new_population

        # Collect stats for the generation
        best_fitness, best_candidate = fitnesses[0]
        worst_fitness, worst_candidate = fitnesses[-1]
        avg_fitness = sum(f[0] for f in fitnesses) / len(fitnesses)
        stats.append({
            "Generation": generation,
            "Best Candidate": best_candidate,
            "Global Best Candidate": global_best_candidate,
            "Worst Candidate": worst_candidate,
            "Best Time": best_fitness,
            "Worst Time": worst_fitness,
            "Global Best Time": global_best_fitness,
            "Average Time": avg_fitness
        })
        print(stats[-1])

    # Final best
    print(f"Global Best candidate: {global_best_candidate} with fitness {global_best_fitness}")

    # Create a DataFrame from stats
    stats_df = pd.DataFrame(stats)
    return stats_df

# %% [markdown]
# ## Example usage

# %%
PASS_POOL = [
    "-fgcse-after-reload",
    "-fipa-cp-clone",
    "-floop-interchange",
    "-floop-unroll-and-jam",
    "-fpeel-loops",
    "-fpredictive-commoning",
    "-fsplit-loops",
    "-fsplit-paths",
    "-ftree-loop-distribution",
    "-ftree-partial-pre",
    "-funswitch-loops",
    "-fvect-cost-model=dynamic",
    "-fversion-loops-for-strides",   
]

# %%
# sources = ["aha-mont64"]
sources = ["edn"]
stats_df = run_ga(sources[0], PASS_POOL, generations=20, pop_size=30, seq_length=5)
# Out:
# Generation 0
# {'Generation': 0, 'Best Candidate': ['-ftree-loop-distribution', '-funswitch-loops', '-fpeel-loops', '-fversion-loops-for-strides', '-floop-unroll-and-jam'], 'Global Best Candidate': ['-ftree-loop-distribution', '-funswitch-loops', '-fpeel-loops', '-fversion-loops-for-strides', '-floop-unroll-and-jam'], 'Worst Candidate': ['-ftree-loop-distribution', '-floop-unroll-and-jam', '-fversion-loops-for-strides', '-floop-interchange', '-funswitch-loops'], 'Best Time': -1882485.6, 'Worst Time': 15175023.4, 'Global Best Time': -1882485.6, 'Average Time': 717588.7366666666}
# Generation 1
# {'Generation': 1, 'Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-interchange', '-fpeel-loops'], 'Global Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-interchange', '-fpeel-loops'], 'Worst Candidate': ['-floop-interchange', '-fversion-loops-for-strides', '-floop-unroll-and-jam', '-ftree-loop-distribution'], 'Best Time': -3039199.8, 'Worst Time': 1236887.3, 'Global Best Time': -3039199.8, 'Average Time': -344298.57}
# Generation 2
# {'Generation': 2, 'Best Candidate': ['-floop-interchange', '-funswitch-loops', '-floop-unroll-and-jam'], 'Global Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-interchange', '-fpeel-loops'], 'Worst Candidate': ['-floop-unroll-and-jam', '-ftree-loop-distribution'], 'Best Time': -1467113.1, 'Worst Time': 2706162.0, 'Global Best Time': -3039199.8, 'Average Time': 98014.59000000001}
# Generation 3
# {'Generation': 3, 'Best Candidate': ['-fversion-loops-for-strides', '-floop-interchange', '-floop-unroll-and-jam'], 'Global Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-interchange', '-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-fversion-loops-for-strides'], 'Best Time': -2635471.2, 'Worst Time': 935294.3, 'Global Best Time': -3039199.8, 'Average Time': -379311.46333333326}
# Generation 4
# {'Generation': 4, 'Best Candidate': ['-fversion-loops-for-strides', '-fpeel-loops', '-floop-interchange'], 'Global Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-interchange', '-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops', '-fpeel-loops'], 'Best Time': -1782123.9, 'Worst Time': 815284.9, 'Global Best Time': -3039199.8, 'Average Time': -420584.3266666666}
# Generation 5
# {'Generation': 5, 'Best Candidate': ['-fpeel-loops', '-floop-interchange', '-floop-unroll-and-jam'], 'Global Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-interchange', '-fpeel-loops'], 'Worst Candidate': ['-ftree-loop-distribution', '-fversion-loops-for-strides'], 'Best Time': -1835009.3, 'Worst Time': 1233413.8, 'Global Best Time': -3039199.8, 'Average Time': -285245.0933333333}
# Generation 6
# {'Generation': 6, 'Best Candidate': ['-floop-interchange', '-fversion-loops-for-strides'], 'Global Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-interchange', '-fpeel-loops'], 'Worst Candidate': ['-floop-unroll-and-jam', '-ftree-loop-distribution', '-floop-interchange'], 'Best Time': -1348860.9, 'Worst Time': 1996624.1, 'Global Best Time': -3039199.8, 'Average Time': -17657.963333333453}
# Generation 7
# {'Generation': 7, 'Best Candidate': ['-funswitch-loops', '-floop-unroll-and-jam'], 'Global Best Candidate': ['-funswitch-loops', '-floop-unroll-and-jam'], 'Worst Candidate': ['-ftree-loop-distribution', '-floop-interchange'], 'Best Time': -5348313.0, 'Worst Time': 9952575.6, 'Global Best Time': -5348313.0, 'Average Time': 133985.6033333334}
# Generation 8
# {'Generation': 8, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-funswitch-loops', '-floop-unroll-and-jam'], 'Worst Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-floop-unroll-and-jam', '-ftree-loop-distribution'], 'Best Time': -1625584.0, 'Worst Time': 3157168.3, 'Global Best Time': -5348313.0, 'Average Time': -207076.60000000003}
# Generation 9
# {'Generation': 9, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -14895863.0, 'Worst Time': 16920765.5, 'Global Best Time': -14895863.0, 'Average Time': -609773.6766666671}
# Generation 10
# {'Generation': 10, 'Best Candidate': ['-fpeel-loops', '-ftree-loop-distribution'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-fpeel-loops', '-fversion-loops-for-strides'], 'Best Time': -13150381.3, 'Worst Time': 719489.5, 'Global Best Time': -14895863.0, 'Average Time': -1740608.3733333335}
# Generation 11
# {'Generation': 11, 'Best Candidate': ['-fpeel-loops', '-funswitch-loops', '-floop-unroll-and-jam', '-ftree-loop-distribution'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops', '-floop-interchange', '-fversion-loops-for-strides'], 'Best Time': -2116982.3, 'Worst Time': 710326.2, 'Global Best Time': -14895863.0, 'Average Time': -372131.56666666665}
# Generation 12
# {'Generation': 12, 'Best Candidate': ['-fpeel-loops', '-funswitch-loops'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops', '-floop-unroll-and-jam', '-ftree-loop-distribution'], 'Best Time': -1952669.7, 'Worst Time': 3314559.0, 'Global Best Time': -14895863.0, 'Average Time': -312149.5700000001}
# Generation 13
# {'Generation': 13, 'Best Candidate': ['-fpeel-loops', '-floop-unroll-and-jam'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-floop-interchange'], 'Best Time': -3283275.6, 'Worst Time': 1704816.7, 'Global Best Time': -14895863.0, 'Average Time': -397623.4200000001}
# Generation 14
# {'Generation': 14, 'Best Candidate': ['-fpeel-loops', '-ftree-loop-distribution'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-floop-interchange', '-funswitch-loops', '-floop-unroll-and-jam'], 'Best Time': -1585934.7, 'Worst Time': 2040087.1, 'Global Best Time': -14895863.0, 'Average Time': -155652.96333333323}
# Generation 15
# {'Generation': 15, 'Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-unroll-and-jam'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-floop-interchange', '-fversion-loops-for-strides', '-funswitch-loops'], 'Best Time': -2442776.7, 'Worst Time': 1261974.0, 'Global Best Time': -14895863.0, 'Average Time': -242817.08333333346}
# Generation 16
# {'Generation': 16, 'Best Candidate': ['-floop-unroll-and-jam', '-fpeel-loops'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -3532017.8, 'Worst Time': 1082268.2, 'Global Best Time': -14895863.0, 'Average Time': -806881.9700000002}
# Generation 17
# {'Generation': 17, 'Best Candidate': ['-ftree-loop-distribution'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -1573726.5, 'Worst Time': 761042.3, 'Global Best Time': -14895863.0, 'Average Time': -270937.7866666667}
# Generation 18
# {'Generation': 18, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -1393262.3, 'Worst Time': 2173455.1, 'Global Best Time': -14895863.0, 'Average Time': -164624.91999999998}
# Generation 19
# {'Generation': 19, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -1418286.9, 'Worst Time': 1900874.7, 'Global Best Time': -14895863.0, 'Average Time': -239355.90666666662}
# Global Best candidate: ['-fpeel-loops'] with fitness -14895863.0

# %%
stats_df
# Out:
#     Generation                                     Best Candidate  \
# 0            0  [-ftree-loop-distribution, -funswitch-loops, -...
# 1            1  [-fversion-loops-for-strides, -funswitch-loops...
# 2            2  [-floop-interchange, -funswitch-loops, -floop-...
# 3            3  [-fversion-loops-for-strides, -floop-interchan...
# 4            4  [-fversion-loops-for-strides, -fpeel-loops, -f...
# 5            5  [-fpeel-loops, -floop-interchange, -floop-unro...
# 6            6  [-floop-interchange, -fversion-loops-for-strides]
# 7            7          [-funswitch-loops, -floop-unroll-and-jam]
# 8            8                                 [-funswitch-loops]
# 9            9                                     [-fpeel-loops]
# 10          10           [-fpeel-loops, -ftree-loop-distribution]
# 11          11  [-fpeel-loops, -funswitch-loops, -floop-unroll...
# 12          12                   [-fpeel-loops, -funswitch-loops]
# 13          13              [-fpeel-loops, -floop-unroll-and-jam]
# 14          14           [-fpeel-loops, -ftree-loop-distribution]
# 15          15  [-funswitch-loops, -ftree-loop-distribution, -...
# 16          16              [-floop-unroll-and-jam, -fpeel-loops]
# 17          17                         [-ftree-loop-distribution]
# 18          18                                 [-funswitch-loops]
# 19          19                               [-floop-interchange]
#
#                                 Global Best Candidate  \
# 0   [-ftree-loop-distribution, -funswitch-loops, -...
# 1   [-fversion-loops-for-strides, -funswitch-loops...
# 2   [-fversion-loops-for-strides, -funswitch-loops...
# 3   [-fversion-loops-for-strides, -funswitch-loops...
# 4   [-fversion-loops-for-strides, -funswitch-loops...
# 5   [-fversion-loops-for-strides, -funswitch-loops...
# 6   [-fversion-loops-for-strides, -funswitch-loops...
# 7           [-funswitch-loops, -floop-unroll-and-jam]
# 8           [-funswitch-loops, -floop-unroll-and-jam]
# 9                                      [-fpeel-loops]
# 10                                     [-fpeel-loops]
# 11                                     [-fpeel-loops]
# 12                                     [-fpeel-loops]
# 13                                     [-fpeel-loops]
# 14                                     [-fpeel-loops]
# 15                                     [-fpeel-loops]
# 16                                     [-fpeel-loops]
# 17                                     [-fpeel-loops]
# 18                                     [-fpeel-loops]
# 19                                     [-fpeel-loops]
#
#                                       Worst Candidate   Best Time  Worst Time  \
# 0   [-ftree-loop-distribution, -floop-unroll-and-j...  -1882485.6  15175023.4
# 1   [-floop-interchange, -fversion-loops-for-strid...  -3039199.8   1236887.3
# 2   [-floop-unroll-and-jam, -ftree-loop-distribution]  -1467113.1   2706162.0
# 3   [-funswitch-loops, -ftree-loop-distribution, -...  -2635471.2    935294.3
# 4                    [-funswitch-loops, -fpeel-loops]  -1782123.9    815284.9
# 5   [-ftree-loop-distribution, -fversion-loops-for...  -1835009.3   1233413.8
# 6   [-floop-unroll-and-jam, -ftree-loop-distributi...  -1348860.9   1996624.1
# 7      [-ftree-loop-distribution, -floop-interchange]  -5348313.0   9952575.6
# 8   [-fversion-loops-for-strides, -funswitch-loops...  -1625584.0   3157168.3
# 9                          [-ftree-loop-distribution] -14895863.0  16920765.5
# 10        [-fpeel-loops, -fversion-loops-for-strides] -13150381.3    719489.5
# 11  [-funswitch-loops, -floop-interchange, -fversi...  -2116982.3    710326.2
# 12  [-funswitch-loops, -floop-unroll-and-jam, -ftr...  -1952669.7   3314559.0
# 13                               [-floop-interchange]  -3283275.6   1704816.7
# 14  [-floop-interchange, -funswitch-loops, -floop-...  -1585934.7   2040087.1
# 15  [-floop-interchange, -fversion-loops-for-strid...  -2442776.7   1261974.0
# 16                            [-floop-unroll-and-jam]  -3532017.8   1082268.2
# 17                         [-ftree-loop-distribution]  -1573726.5    761042.3
# 18                                     [-fpeel-loops]  -1393262.3   2173455.1
# 19                                 [-funswitch-loops]  -1418286.9   1900874.7
#
#     Global Best Time  Average Time
# 0         -1882485.6  7.175887e+05
# 1         -3039199.8 -3.442986e+05
# 2         -3039199.8  9.801459e+04
# 3         -3039199.8 -3.793115e+05
# 4         -3039199.8 -4.205843e+05
# 5         -3039199.8 -2.852451e+05
# 6         -3039199.8 -1.765796e+04
# 7         -5348313.0  1.339856e+05
# 8         -5348313.0 -2.070766e+05
# 9        -14895863.0 -6.097737e+05
# 10       -14895863.0 -1.740608e+06
# 11       -14895863.0 -3.721316e+05
# 12       -14895863.0 -3.121496e+05
# 13       -14895863.0 -3.976234e+05
# 14       -14895863.0 -1.556530e+05
# 15       -14895863.0 -2.428171e+05
# 16       -14895863.0 -8.068820e+05
# 17       -14895863.0 -2.709378e+05
# 18       -14895863.0 -1.646249e+05
# 19       -14895863.0 -2.393559e+05

# %%
# apply_passes("edn", [])
input_bc = "dijkstra"
apply_passes(input_bc, [])

# subprocess.run(["mv", f"{input_bc}/{input_bc}", f"{input_bc}/{input_bc}_base"], cwd= "./beebs/src", capture_output=True, text=True, check=True)
apply_passes(input_bc, ["-funroll-all-loops", "-finline-functions", "-fipa-cp-clone", "-fpredictive-commoning", "-ftree-loop-distribution", "-ftree-partial-pre", "-funswitch-loops", "-fvect-cost-model=dynamic", "-fsplit-loops", "-fsplit-paths", "-fversion-loops-for-strides"])
# result = apply_passes(input_bc, ["-O2", "-funroll-loops"])
# print(result)
opt_time = measure_runtime(input_bc, 50)
# -75552263.64
# -73332604.12
# -77537008.64
# -75777408.08
# -74279599.84
# -75036094.64

# dump_cmd = ["riscv64-unknown-elf-objdump", "-D", f"beebs/src/{input_bc}/{input_bc}", ">", f"{input_bc}.dump", "&&", "riscv64-unknown-elf-objdump","-D", f"beebs/src/{input_bc}/{input_bc}_base", ">", f"{input_bc}_base.dump"]
# subprocess.run(" ".join(dump_cmd), shell=True, capture_output=True, text=True, check=True)

opt_time
# Out:
# -76004866.36

# %%
stats_df.to_csv("results/fibcall_stats.csv", index=False)

# %%
stats_df.iloc[19]["Global Best Candidate"]
# Out:
# ['-fvect-cost-model=dynamic']

# %%
stats_df.iloc[19]["Global Best Candidate"]
# Out:
# ['-fpredictive-commoning', '-finline-functions']

# %%
stats_df.iloc[19]["Global Best Candidate"]
# Out:
# ['-fpredictive-commoning']

# %%
stats_df
# Out:
#    Generation                                     Best Candidate  \
# 0           0  [-fvect-cost-model=dynamic, -fpredictive-commo...
# 1           1  [-fversion-loops-for-strides, -floop-unroll-an...
# 2           2  [-ftree-loop-distribution, -finline-functions,...
# 3           3                [-ftree-partial-pre, -fsplit-paths]
# 4           4        [-ftree-partial-pre, -floop-unroll-and-jam]
# 5           5             [-fpredictive-commoning, -fpeel-loops]
# 6           6                      [-fversion-loops-for-strides]
# 7           7                               [-ftree-partial-pre]
# 8           8        [-ftree-partial-pre, -floop-unroll-and-jam]
# 9           9               [-fipa-cp-clone, -ftree-partial-pre]
#
#                                      Worst Candidate     Best Time  \
# 0  [-fpeel-loops, -fsplit-loops, -fgcse-after-rel...  1.520303e+07
# 1       [-fsplit-paths, -fpeel-loops, -fsplit-loops]  1.528405e+07
# 2  [-fsplit-paths, -funswitch-loops, -fgcse-after...  1.545591e+07
# 3  [-ftree-loop-distribution, -finline-functions,...  1.563720e+07
# 4                               [-ftree-partial-pre]  1.537416e+07
# 5        [-ftree-partial-pre, -floop-unroll-and-jam]  1.551668e+07
# 6                               [-ftree-partial-pre]  1.463224e+07
# 7                               [-ftree-partial-pre]  1.386664e+07
# 8                      [-fversion-loops-for-strides]  1.533058e+07
# 9                      [-fversion-loops-for-strides]  1.515087e+07
#
#      Worst Time  Average Time  \
# 0  1.714250e+07  1.589055e+07
# 1  1.634000e+07  1.586876e+07
# 2  1.615028e+07  1.590482e+07
# 3  1.631969e+07  1.599475e+07
# 4  1.721009e+07  1.629896e+07
# 5  1.696686e+07  1.595501e+07
# 6  3.784631e+07  1.821418e+07
# 7  4.394374e+07  1.771352e+07
# 8  1.722007e+07  1.611287e+07
# 9  1.707936e+07  1.607122e+07
#
#                                Global Best Candidate  Global Best Time
# 0  [-fvect-cost-model=dynamic, -fpredictive-commo...      1.520303e+07
# 1  [-fvect-cost-model=dynamic, -fpredictive-commo...      1.520303e+07
# 2  [-fvect-cost-model=dynamic, -fpredictive-commo...      1.520303e+07
# 3  [-fvect-cost-model=dynamic, -fpredictive-commo...      1.520303e+07
# 4  [-fvect-cost-model=dynamic, -fpredictive-commo...      1.520303e+07
# 5  [-fvect-cost-model=dynamic, -fpredictive-commo...      1.520303e+07
# 6                      [-fversion-loops-for-strides]      1.463224e+07
# 7                               [-ftree-partial-pre]      1.386664e+07
# 8                               [-ftree-partial-pre]      1.386664e+07
# 9                               [-ftree-partial-pre]      1.386664e+07

# %%
stats_df.iloc[2]
# Out:
# Generation                                                         2
# Best Candidate     [-fversion-loops-for-strides, -ftree-loop-dist...
# Worst Candidate                                     [-fipa-cp-clone]
# Best Time                                                   0.004494
# Worst Time                                                  0.005263
# Average Time                                                0.004587
# Name: 2, dtype: object

# %%
sources = ["sglib-listsort", # 1 
           "dtoa", # 2
           "fac", # 3

           "trio-snprintf", # 1 
           "fibcall", # 2
           "crc32", # 3

           "ctl-vector", # 1
           "nettle-arcfour", # 2
           "template" # 3
           ] 

for source in sources:
    print(f"Running GA for {source}")
    stats_df = run_ga(sources[0], PASS_POOL, generations=30, pop_size=40, seq_length=5)
    stats_df.to_csv(f"results/{source}_stats.csv", index=False)
# Out:
# Running GA for sglib-listsort
# Generation 0
# {'Generation': 0, 'Best Candidate': ['-ftree-partial-pre', '-floop-interchange', '-fversion-loops-for-strides', '-ftree-loop-distribution', '-fgcse-after-reload'], 'Global Best Candidate': ['-ftree-partial-pre', '-floop-interchange', '-fversion-loops-for-strides', '-ftree-loop-distribution', '-fgcse-after-reload'], 'Worst Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic', '-fsplit-paths', '-fversion-loops-for-strides', '-fipa-cp-clone'], 'Best Time': -7258341.7, 'Worst Time': 8824510.3, 'Global Best Time': -7258341.7, 'Average Time': -501196.6980000005}
# Generation 1
# {'Generation': 1, 'Best Candidate': ['-fsplit-paths', '-fvect-cost-model=dynamic', '-fgcse-after-reload', '-floop-interchange'], 'Global Best Candidate': ['-fsplit-paths', '-fvect-cost-model=dynamic', '-fgcse-after-reload', '-floop-interchange'], 'Worst Candidate': ['-ftree-partial-pre', '-floop-interchange', '-ftree-loop-distribution', '-fversion-loops-for-strides'], 'Best Time': -9758293.4, 'Worst Time': 7246715.7, 'Global Best Time': -9758293.4, 'Average Time': -929631.9420000005}
# Generation 2
# {'Generation': 2, 'Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-fvect-cost-model=dynamic', '-fpeel-loops', '-funswitch-loops', '-fsplit-paths'], 'Best Time': -10880197.4, 'Worst Time': 8946042.5, 'Global Best Time': -10880197.4, 'Average Time': -521575.5000000003}
# Generation 3
# {'Generation': 3, 'Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-fipa-cp-clone', '-fvect-cost-model=dynamic', '-fversion-loops-for-strides'], 'Best Time': -7907816.3, 'Worst Time': 6714531.4, 'Global Best Time': -10880197.4, 'Average Time': -1068386.9839999997}
# Generation 4
# {'Generation': 4, 'Best Candidate': ['-ftree-partial-pre', '-fipa-cp-clone', '-floop-interchange', '-fpeel-loops'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -8039775.0, 'Worst Time': 8624036.5, 'Global Best Time': -10880197.4, 'Average Time': -628506.0360000001}
# Generation 5
# {'Generation': 5, 'Best Candidate': ['-floop-interchange', '-fgcse-after-reload', '-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-fvect-cost-model=dynamic', '-floop-unroll-and-jam'], 'Best Time': -10813386.4, 'Worst Time': 13739901.0, 'Global Best Time': -10880197.4, 'Average Time': -732590.494000001}
# Generation 6
# {'Generation': 6, 'Best Candidate': ['-fipa-cp-clone'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-fpeel-loops', '-fsplit-loops'], 'Best Time': -7753496.0, 'Worst Time': 10144291.8, 'Global Best Time': -10880197.4, 'Average Time': -765905.666}
# Generation 7
# {'Generation': 7, 'Best Candidate': ['-fversion-loops-for-strides'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -10640886.0, 'Worst Time': 5516345.2, 'Global Best Time': -10880197.4, 'Average Time': -1545482.4319999998}
# Generation 8
# {'Generation': 8, 'Best Candidate': ['-fipa-cp-clone', '-fversion-loops-for-strides', '-fpeel-loops'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -7031713.8, 'Worst Time': 5152004.0, 'Global Best Time': -10880197.4, 'Average Time': -1255852.3520000004}
# Generation 9
# {'Generation': 9, 'Best Candidate': ['-fvect-cost-model=dynamic', '-fpredictive-commoning'], 'Global Best Candidate': ['-fgcse-after-reload', '-ftree-loop-distribution', '-fsplit-loops'], 'Worst Candidate': ['-ftree-partial-pre', '-funswitch-loops'], 'Best Time': -7956151.8, 'Worst Time': 11245198.7, 'Global Best Time': -10880197.4, 'Average Time': -1496153.0979999998}
# Generation 10
# {'Generation': 10, 'Best Candidate': ['-fvect-cost-model=dynamic', '-fpredictive-commoning'], 'Global Best Candidate': ['-fvect-cost-model=dynamic', '-fpredictive-commoning'], 'Worst Candidate': ['-fpeel-loops', '-fsplit-loops', '-ftree-partial-pre'], 'Best Time': -11246010.2, 'Worst Time': 8745707.4, 'Global Best Time': -11246010.2, 'Average Time': -1337004.318}
# Generation 11
# {'Generation': 11, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-fvect-cost-model=dynamic', '-floop-interchange', '-ftree-loop-distribution'], 'Best Time': -11361965.6, 'Worst Time': 8228774.0, 'Global Best Time': -11361965.6, 'Average Time': -679379.6700000009}
# Generation 12
# {'Generation': 12, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpeel-loops'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -10758316.7, 'Worst Time': 6174526.7, 'Global Best Time': -11361965.6, 'Average Time': -1093540.8659999997}
# Generation 13
# {'Generation': 13, 'Best Candidate': ['-fsplit-loops', '-fsplit-paths'], 'Global Best Candidate': ['-fsplit-loops', '-fsplit-paths'], 'Worst Candidate': ['-ftree-partial-pre', '-fipa-cp-clone', '-fvect-cost-model=dynamic'], 'Best Time': -11455115.6, 'Worst Time': 8269127.7, 'Global Best Time': -11455115.6, 'Average Time': -1413379.3679999989}
# Generation 14
# {'Generation': 14, 'Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution'], 'Worst Candidate': ['-ftree-loop-distribution', '-fgcse-after-reload'], 'Best Time': -11818798.5, 'Worst Time': 8122322.1, 'Global Best Time': -11818798.5, 'Average Time': -438496.35200000065}
# Generation 15
# {'Generation': 15, 'Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Worst Candidate': ['-floop-interchange', '-fvect-cost-model=dynamic'], 'Best Time': -12618631.0, 'Worst Time': 6942564.9, 'Global Best Time': -12618631.0, 'Average Time': -433132.2320000002}
# Generation 16
# {'Generation': 16, 'Best Candidate': ['-fversion-loops-for-strides'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -6556447.6, 'Worst Time': 6109367.9, 'Global Best Time': -12618631.0, 'Average Time': -387993.81599999993}
# Generation 17
# {'Generation': 17, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Worst Candidate': ['-floop-unroll-and-jam', '-ftree-loop-distribution'], 'Best Time': -11054709.4, 'Worst Time': 6425277.8, 'Global Best Time': -12618631.0, 'Average Time': -1292136.1940000001}
# Generation 18
# {'Generation': 18, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Worst Candidate': ['-fversion-loops-for-strides'], 'Best Time': -9909742.5, 'Worst Time': 10144654.0, 'Global Best Time': -12618631.0, 'Average Time': 547638.1540000002}
# Generation 19
# {'Generation': 19, 'Best Candidate': ['-fipa-cp-clone', '-fsplit-loops'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Worst Candidate': ['-floop-unroll-and-jam', '-funswitch-loops', '-fpredictive-commoning'], 'Best Time': -6293539.0, 'Worst Time': 8008413.1, 'Global Best Time': -12618631.0, 'Average Time': -857351.1580000005}
# Generation 20
# {'Generation': 20, 'Best Candidate': ['-fpredictive-commoning', '-fversion-loops-for-strides'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -7154965.5, 'Worst Time': 6080852.8, 'Global Best Time': -12618631.0, 'Average Time': -536089.3159999999}
# Generation 21
# {'Generation': 21, 'Best Candidate': ['-floop-unroll-and-jam'], 'Global Best Candidate': ['-funswitch-loops', '-ftree-loop-distribution', '-floop-interchange', '-fgcse-after-reload'], 'Worst Candidate': ['-fsplit-paths'], 'Best Time': -10502759.6, 'Worst Time': 5416124.8, 'Global Best Time': -12618631.0, 'Average Time': -1416561.2839999995}
# Generation 22
# {'Generation': 22, 'Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -14844090.3, 'Worst Time': 5405426.2, 'Global Best Time': -14844090.3, 'Average Time': -1154392.0300000003}
# Generation 23
# {'Generation': 23, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-partial-pre'], 'Best Time': -6509984.4, 'Worst Time': 6016846.0, 'Global Best Time': -14844090.3, 'Average Time': -143263.556}
# Generation 24
# {'Generation': 24, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fsplit-loops', '-fgcse-after-reload'], 'Best Time': -10314691.0, 'Worst Time': 9685858.2, 'Global Best Time': -14844090.3, 'Average Time': -834158.2719999999}
# Generation 25
# {'Generation': 25, 'Best Candidate': ['-funswitch-loops', '-fversion-loops-for-strides'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -7085462.8, 'Worst Time': 8365098.8, 'Global Best Time': -14844090.3, 'Average Time': 96814.48800000014}
# Generation 26
# {'Generation': 26, 'Best Candidate': ['-fversion-loops-for-strides'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -8151835.7, 'Worst Time': 5810205.6, 'Global Best Time': -14844090.3, 'Average Time': -806237.6379999996}
# Generation 27
# {'Generation': 27, 'Best Candidate': ['-fsplit-loops', '-ftree-loop-distribution', '-ftree-partial-pre', '-fpeel-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fvect-cost-model=dynamic'], 'Best Time': -8454476.8, 'Worst Time': 8273436.4, 'Global Best Time': -14844090.3, 'Average Time': -1657617.001999999}
# Generation 28
# {'Generation': 28, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-floop-interchange'], 'Best Time': -8845898.5, 'Worst Time': 9446288.2, 'Global Best Time': -14844090.3, 'Average Time': -946635.3579999998}
# Generation 29
# {'Generation': 29, 'Best Candidate': ['-floop-interchange', '-ftree-partial-pre', '-fpeel-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fvect-cost-model=dynamic'], 'Best Time': -5796066.0, 'Worst Time': 4603303.0, 'Global Best Time': -14844090.3, 'Average Time': -1159747.1139999996}
# Generation 30
# {'Generation': 30, 'Best Candidate': ['-floop-unroll-and-jam'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -11350066.7, 'Worst Time': 7201480.7, 'Global Best Time': -14844090.3, 'Average Time': -1816307.019999999}
# Generation 31
# {'Generation': 31, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fversion-loops-for-strides', '-fvect-cost-model=dynamic'], 'Best Time': -7891898.6, 'Worst Time': 7485409.7, 'Global Best Time': -14844090.3, 'Average Time': -406758.966}
# Generation 32
# {'Generation': 32, 'Best Candidate': ['-ftree-loop-distribution', '-floop-interchange'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fipa-cp-clone'], 'Best Time': -12641536.9, 'Worst Time': 5359086.9, 'Global Best Time': -14844090.3, 'Average Time': -1033024.2100000002}
# Generation 33
# {'Generation': 33, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -13176188.9, 'Worst Time': 7288389.8, 'Global Best Time': -14844090.3, 'Average Time': -950244.3279999999}
# Generation 34
# {'Generation': 34, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -6785028.0, 'Worst Time': 5697902.9, 'Global Best Time': -14844090.3, 'Average Time': -419000.8}
# Generation 35
# {'Generation': 35, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -9845938.6, 'Worst Time': 9412997.8, 'Global Best Time': -14844090.3, 'Average Time': 21986.31800000083}
# Generation 36
# {'Generation': 36, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -8298631.6, 'Worst Time': 6423189.7, 'Global Best Time': -14844090.3, 'Average Time': -1355258.8}
# Generation 37
# {'Generation': 37, 'Best Candidate': ['-fpredictive-commoning'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -11043258.0, 'Worst Time': 5224078.3, 'Global Best Time': -14844090.3, 'Average Time': -1093349.826}
# Generation 38
# {'Generation': 38, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -10392009.3, 'Worst Time': 8403980.9, 'Global Best Time': -14844090.3, 'Average Time': -1126090.1779999998}
# Generation 39
# {'Generation': 39, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fsplit-paths'], 'Best Time': -14833440.0, 'Worst Time': 5517394.3, 'Global Best Time': -14844090.3, 'Average Time': -1843652.1879999992}
# Generation 40
# {'Generation': 40, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -7705290.9, 'Worst Time': 9110283.4, 'Global Best Time': -14844090.3, 'Average Time': -584831.4580000001}
# Generation 41
# {'Generation': 41, 'Best Candidate': ['-fversion-loops-for-strides'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -9486787.1, 'Worst Time': 7016957.5, 'Global Best Time': -14844090.3, 'Average Time': -278271.6220000002}
# Generation 42
# {'Generation': 42, 'Best Candidate': ['-fversion-loops-for-strides'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -7335554.9, 'Worst Time': 5359230.8, 'Global Best Time': -14844090.3, 'Average Time': -1287286.7899999998}
# Generation 43
# {'Generation': 43, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -7949772.1, 'Worst Time': 6515234.7, 'Global Best Time': -14844090.3, 'Average Time': -293025.4320000007}
# Generation 44
# {'Generation': 44, 'Best Candidate': ['-fsplit-paths'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -9394226.2, 'Worst Time': 8189082.3, 'Global Best Time': -14844090.3, 'Average Time': -570170.8319999999}
# Generation 45
# {'Generation': 45, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -6843301.4, 'Worst Time': 7958295.4, 'Global Best Time': -14844090.3, 'Average Time': -724554.2420000009}
# Generation 46
# {'Generation': 46, 'Best Candidate': ['-fpredictive-commoning'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-partial-pre'], 'Best Time': -10955928.6, 'Worst Time': 6782548.4, 'Global Best Time': -14844090.3, 'Average Time': -1318292.7040000006}
# Generation 47
# {'Generation': 47, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -10871984.7, 'Worst Time': 6016549.0, 'Global Best Time': -14844090.3, 'Average Time': -1138037.6679999987}
# Generation 48
# {'Generation': 48, 'Best Candidate': ['-floop-unroll-and-jam'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -5847440.2, 'Worst Time': 8096683.9, 'Global Best Time': -14844090.3, 'Average Time': 61845.78799999991}
# Generation 49
# {'Generation': 49, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fipa-cp-clone'], 'Best Time': -8113157.8, 'Worst Time': 11436018.1, 'Global Best Time': -14844090.3, 'Average Time': 190314.18199999965}
# Generation 50
# {'Generation': 50, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fversion-loops-for-strides'], 'Best Time': -10363066.3, 'Worst Time': 7436725.9, 'Global Best Time': -14844090.3, 'Average Time': -1013648.1579999989}
# Generation 51
# {'Generation': 51, 'Best Candidate': ['-fipa-cp-clone'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -7710077.1, 'Worst Time': 7404748.1, 'Global Best Time': -14844090.3, 'Average Time': -1272124.7959999999}
# Generation 52
# {'Generation': 52, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -9579475.4, 'Worst Time': 6928224.2, 'Global Best Time': -14844090.3, 'Average Time': -491444.6579999996}
# Generation 53
# {'Generation': 53, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -10983330.8, 'Worst Time': 5954944.8, 'Global Best Time': -14844090.3, 'Average Time': -1038378.6440000013}
# Generation 54
# {'Generation': 54, 'Best Candidate': ['-fipa-cp-clone'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fipa-cp-clone'], 'Best Time': -8002618.2, 'Worst Time': 6615371.7, 'Global Best Time': -14844090.3, 'Average Time': -1835792.9359999998}
# Generation 55
# {'Generation': 55, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -10822404.0, 'Worst Time': 7965216.6, 'Global Best Time': -14844090.3, 'Average Time': -956552.6899999992}
# Generation 56
# {'Generation': 56, 'Best Candidate': ['-ftree-loop-distribution'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-floop-interchange'], 'Best Time': -7688862.3, 'Worst Time': 6228977.2, 'Global Best Time': -14844090.3, 'Average Time': -1403249.9599999997}
# Generation 57
# {'Generation': 57, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -12338995.3, 'Worst Time': 6546754.7, 'Global Best Time': -14844090.3, 'Average Time': -2137697.1240000003}
# Generation 58
# {'Generation': 58, 'Best Candidate': ['-fsplit-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -11448411.4, 'Worst Time': 5527688.2, 'Global Best Time': -14844090.3, 'Average Time': -1751862.7140000004}
# Generation 59
# {'Generation': 59, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -8108608.8, 'Worst Time': 5792379.3, 'Global Best Time': -14844090.3, 'Average Time': -701081.0480000001}
# Generation 60
# {'Generation': 60, 'Best Candidate': ['-fsplit-paths'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fipa-cp-clone'], 'Best Time': -8930216.3, 'Worst Time': 10096674.7, 'Global Best Time': -14844090.3, 'Average Time': -434286.3019999998}
# Generation 61
# {'Generation': 61, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-floop-interchange'], 'Best Time': -10896801.7, 'Worst Time': 7246649.8, 'Global Best Time': -14844090.3, 'Average Time': -1162635.6120000004}
# Generation 62
# {'Generation': 62, 'Best Candidate': ['-fsplit-paths'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-partial-pre'], 'Best Time': -11045198.8, 'Worst Time': 6515027.0, 'Global Best Time': -14844090.3, 'Average Time': -1486220.626}
# Generation 63
# {'Generation': 63, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -8559609.7, 'Worst Time': 7657386.2, 'Global Best Time': -14844090.3, 'Average Time': -510559.6039999986}
# Generation 64
# {'Generation': 64, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -8649154.8, 'Worst Time': 8418863.7, 'Global Best Time': -14844090.3, 'Average Time': -654350.2300000001}
# Generation 65
# {'Generation': 65, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-fpredictive-commoning', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -10270262.3, 'Worst Time': 6538504.2, 'Global Best Time': -14844090.3, 'Average Time': -436515.8679999999}
# Generation 66
# {'Generation': 66, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -32020933.2, 'Worst Time': 7746565.9, 'Global Best Time': -32020933.2, 'Average Time': -1874874.2640000014}
# Generation 67
# {'Generation': 67, 'Best Candidate': ['-fipa-cp-clone'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -9212891.0, 'Worst Time': 6354266.5, 'Global Best Time': -32020933.2, 'Average Time': -1271144.7000000007}
# Generation 68
# {'Generation': 68, 'Best Candidate': ['-fsplit-paths'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -7455486.9, 'Worst Time': 9793933.5, 'Global Best Time': -32020933.2, 'Average Time': -801390.5519999996}
# Generation 69
# {'Generation': 69, 'Best Candidate': ['-floop-unroll-and-jam'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fversion-loops-for-strides'], 'Best Time': -13270138.9, 'Worst Time': 7987442.6, 'Global Best Time': -32020933.2, 'Average Time': -912659.6639999994}
# Generation 70
# {'Generation': 70, 'Best Candidate': ['-fsplit-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-floop-unroll-and-jam'], 'Best Time': -7018186.1, 'Worst Time': 8801338.7, 'Global Best Time': -32020933.2, 'Average Time': -856992.8739999991}
# Generation 71
# {'Generation': 71, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -8290896.7, 'Worst Time': 6432136.9, 'Global Best Time': -32020933.2, 'Average Time': -2214883.2599999984}
# Generation 72
# {'Generation': 72, 'Best Candidate': ['-fsplit-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fversion-loops-for-strides'], 'Best Time': -9088160.0, 'Worst Time': 6451703.7, 'Global Best Time': -32020933.2, 'Average Time': -1181912.9120000005}
# Generation 73
# {'Generation': 73, 'Best Candidate': ['-fipa-cp-clone'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -7995697.0, 'Worst Time': 5707140.0, 'Global Best Time': -32020933.2, 'Average Time': -688747.8299999993}
# Generation 74
# {'Generation': 74, 'Best Candidate': ['-fversion-loops-for-strides'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-paths'], 'Best Time': -8938557.4, 'Worst Time': 12001555.5, 'Global Best Time': -32020933.2, 'Average Time': -50603.29000000104}
# Generation 75
# {'Generation': 75, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -10304335.4, 'Worst Time': 6243820.1, 'Global Best Time': -32020933.2, 'Average Time': -1306499.6020000004}
# Generation 76
# {'Generation': 76, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -8406695.1, 'Worst Time': 6523375.5, 'Global Best Time': -32020933.2, 'Average Time': -1570269.744}
# Generation 77
# {'Generation': 77, 'Best Candidate': ['-ftree-loop-distribution'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-floop-interchange'], 'Best Time': -9247521.1, 'Worst Time': 5852914.9, 'Global Best Time': -32020933.2, 'Average Time': -1295351.6000000006}
# Generation 78
# {'Generation': 78, 'Best Candidate': ['-fsplit-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -9791582.3, 'Worst Time': 10060329.7, 'Global Best Time': -32020933.2, 'Average Time': -960156.4759999987}
# Generation 79
# {'Generation': 79, 'Best Candidate': ['-fsplit-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-ftree-partial-pre'], 'Best Time': -11588914.5, 'Worst Time': 6415935.9, 'Global Best Time': -32020933.2, 'Average Time': -912473.9660000004}
# Generation 80
# {'Generation': 80, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fversion-loops-for-strides'], 'Best Time': -6693427.1, 'Worst Time': 6012759.9, 'Global Best Time': -32020933.2, 'Average Time': -922054.4920000009}
# Generation 81
# {'Generation': 81, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fversion-loops-for-strides'], 'Best Time': -8078961.6, 'Worst Time': 8819038.4, 'Global Best Time': -32020933.2, 'Average Time': -944699.0380000003}
# Generation 82
# {'Generation': 82, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fvect-cost-model=dynamic'], 'Best Time': -12051078.6, 'Worst Time': 6312808.7, 'Global Best Time': -32020933.2, 'Average Time': -742664.1759999997}
# Generation 83
# {'Generation': 83, 'Best Candidate': ['-ftree-partial-pre'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -12782201.7, 'Worst Time': 11460454.0, 'Global Best Time': -32020933.2, 'Average Time': -1204574.2880000004}
# Generation 84
# {'Generation': 84, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -11419410.8, 'Worst Time': 7946429.4, 'Global Best Time': -32020933.2, 'Average Time': -753857.8360000007}
# Generation 85
# {'Generation': 85, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-floop-interchange'], 'Best Time': -9106091.5, 'Worst Time': 10518465.1, 'Global Best Time': -32020933.2, 'Average Time': -529294.2960000001}
# Generation 86
# {'Generation': 86, 'Best Candidate': ['-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -9177486.6, 'Worst Time': 11474808.5, 'Global Best Time': -32020933.2, 'Average Time': -719938.9900000003}
# Generation 87
# {'Generation': 87, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-floop-interchange'], 'Best Time': -10819537.8, 'Worst Time': 11085865.3, 'Global Best Time': -32020933.2, 'Average Time': -623547.2080000001}
# Generation 88
# {'Generation': 88, 'Best Candidate': ['-fpredictive-commoning'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-paths'], 'Best Time': -9142932.5, 'Worst Time': 7892020.8, 'Global Best Time': -32020933.2, 'Average Time': -1041761.384}
# Generation 89
# {'Generation': 89, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -7183202.0, 'Worst Time': 6063110.8, 'Global Best Time': -32020933.2, 'Average Time': -435999.7940000003}
# Generation 90
# {'Generation': 90, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -7830246.1, 'Worst Time': 6537193.3, 'Global Best Time': -32020933.2, 'Average Time': -450008.5740000006}
# Generation 91
# {'Generation': 91, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-ftree-partial-pre'], 'Best Time': -13129063.0, 'Worst Time': 12919531.1, 'Global Best Time': -32020933.2, 'Average Time': -218113.76000000004}
# Generation 92
# {'Generation': 92, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -8871788.2, 'Worst Time': 6582692.7, 'Global Best Time': -32020933.2, 'Average Time': -941477.5760000006}
# Generation 93
# {'Generation': 93, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -10152507.8, 'Worst Time': 3464121.1, 'Global Best Time': -32020933.2, 'Average Time': -1398850.1880000008}
# Generation 94
# {'Generation': 94, 'Best Candidate': ['-fsplit-paths'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -11545119.3, 'Worst Time': 9889825.9, 'Global Best Time': -32020933.2, 'Average Time': 154589.17}
# Generation 95
# {'Generation': 95, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-paths'], 'Best Time': -10166854.1, 'Worst Time': 4923598.9, 'Global Best Time': -32020933.2, 'Average Time': -1483359.4559999993}
# Generation 96
# {'Generation': 96, 'Best Candidate': ['-floop-unroll-and-jam'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -10092033.8, 'Worst Time': 5402255.9, 'Global Best Time': -32020933.2, 'Average Time': -1312711.8259999994}
# Generation 97
# {'Generation': 97, 'Best Candidate': ['-fipa-cp-clone'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -14132422.5, 'Worst Time': 5906028.7, 'Global Best Time': -32020933.2, 'Average Time': -1459293.1979999996}
# Generation 98
# {'Generation': 98, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-ftree-loop-distribution'], 'Best Time': -8110073.0, 'Worst Time': 7375694.3, 'Global Best Time': -32020933.2, 'Average Time': -921257.9159999995}
# Generation 99
# {'Generation': 99, 'Best Candidate': ['-funswitch-loops'], 'Global Best Candidate': ['-ftree-partial-pre'], 'Worst Candidate': ['-fsplit-loops'], 'Best Time': -8683587.1, 'Worst Time': 6042487.1, 'Global Best Time': -32020933.2, 'Average Time': -670757.8580000001}
# Global Best candidate: ['-ftree-partial-pre'] with fitness -32020933.2
# Running GA for trio-snprintf
# Generation 0
# {'Generation': 0, 'Best Candidate': ['-fsplit-loops', '-floop-interchange', '-ftree-loop-distribution', '-fversion-loops-for-strides', '-funswitch-loops'], 'Global Best Candidate': ['-fsplit-loops', '-floop-interchange', '-ftree-loop-distribution', '-fversion-loops-for-strides', '-funswitch-loops'], 'Worst Candidate': ['-fsplit-loops', '-floop-interchange', '-fvect-cost-model=dynamic', '-fpredictive-commoning', '-funswitch-loops'], 'Best Time': -9084601.9, 'Worst Time': 7771947.4, 'Global Best Time': -9084601.9, 'Average Time': -582579.0120000005}
# Generation 1
# {'Generation': 1, 'Best Candidate': ['-funswitch-loops', '-fipa-cp-clone', '-fsplit-loops', '-ftree-loop-distribution'], 'Global Best Candidate': ['-funswitch-loops', '-fipa-cp-clone', '-fsplit-loops', '-ftree-loop-distribution'], 'Worst Candidate': ['-fversion-loops-for-strides', '-floop-unroll-and-jam', '-fpeel-loops', '-fvect-cost-model=dynamic'], 'Best Time': -10629896.8, 'Worst Time': 6735177.5, 'Global Best Time': -10629896.8, 'Average Time': -1190862.8280000004}
# Generation 2
# {'Generation': 2, 'Best Candidate': ['-floop-unroll-and-jam', '-fipa-cp-clone', '-ftree-partial-pre', '-fvect-cost-model=dynamic'], 'Global Best Candidate': ['-floop-unroll-and-jam', '-fipa-cp-clone', '-ftree-partial-pre', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fpeel-loops', '-fsplit-loops', '-fsplit-paths', '-ftree-partial-pre'], 'Best Time': -11855569.4, 'Worst Time': 9640425.8, 'Global Best Time': -11855569.4, 'Average Time': -737275.99}
# Generation 3
# {'Generation': 3, 'Best Candidate': ['-ftree-loop-distribution', '-funswitch-loops'], 'Global Best Candidate': ['-floop-unroll-and-jam', '-fipa-cp-clone', '-ftree-partial-pre', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -7774366.4, 'Worst Time': 8735476.4, 'Global Best Time': -11855569.4, 'Average Time': -1550094.9479999999}
# Generation 4
# {'Generation': 4, 'Best Candidate': ['-fsplit-paths', '-fgcse-after-reload', '-fversion-loops-for-strides', '-funswitch-loops'], 'Global Best Candidate': ['-floop-unroll-and-jam', '-fipa-cp-clone', '-ftree-partial-pre', '-fvect-cost-model=dynamic'], 'Worst Candidate': ['-ftree-loop-distribution', '-fvect-cost-model=dynamic'], 'Best Time': -9602818.9, 'Worst Time': 6883117.1, 'Global Best Time': -11855569.4, 'Average Time': -1250168.038}
# Generation 5
# {'Generation': 5, 'Best Candidate': ['-fsplit-paths', '-fversion-loops-for-strides'], 'Global Best Candidate': ['-fsplit-paths', '-fversion-loops-for-strides'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -12501864.1, 'Worst Time': 10339941.2, 'Global Best Time': -12501864.1, 'Average Time': -644801.7300000001}
# Generation 6
# {'Generation': 6, 'Best Candidate': ['-ftree-loop-distribution', '-fvect-cost-model=dynamic', '-fsplit-paths'], 'Global Best Candidate': ['-fsplit-paths', '-fversion-loops-for-strides'], 'Worst Candidate': ['-fgcse-after-reload'], 'Best Time': -10147520.5, 'Worst Time': 7623672.7, 'Global Best Time': -12501864.1, 'Average Time': -487699.13599999994}
# Generation 7
# {'Generation': 7, 'Best Candidate': ['-fversion-loops-for-strides'], 'Global Best Candidate': ['-fsplit-paths', '-fversion-loops-for-strides'], 'Worst Candidate': ['-fvect-cost-model=dynamic', '-fpredictive-commoning', '-fpeel-loops'], 'Best Time': -9194437.3, 'Worst Time': 8890670.3, 'Global Best Time': -12501864.1, 'Average Time': -727343.4059999994}
# Generation 8
# {'Generation': 8, 'Best Candidate': ['-fsplit-loops', '-fipa-cp-clone'], 'Global Best Candidate': ['-fsplit-paths', '-fversion-loops-for-strides'], 'Worst Candidate': ['-fsplit-loops', '-funswitch-loops', '-fipa-cp-clone', '-ftree-loop-distribution'], 'Best Time': -12225892.8, 'Worst Time': 7425346.7, 'Global Best Time': -12501864.1, 'Average Time': -2347863.8860000004}
# Generation 9
# {'Generation': 9, 'Best Candidate': ['-fpredictive-commoning'], 'Global Best Candidate': ['-fsplit-paths', '-fversion-loops-for-strides'], 'Worst Candidate': ['-ftree-loop-distribution', '-funswitch-loops', '-fvect-cost-model=dynamic'], 'Best Time': -9114295.0, 'Worst Time': 7895878.0, 'Global Best Time': -12501864.1, 'Average Time': -1081095.1479999986}
# Generation 10
# {'Generation': 10, 'Best Candidate': ['-fversion-loops-for-strides', '-fpredictive-commoning', '-fsplit-paths'], 'Global Best Candidate': ['-fsplit-paths', '-fversion-loops-for-strides'], 'Worst Candidate': ['-fpeel-loops'], 'Best Time': -8526371.6, 'Worst Time': 7596285.2, 'Global Best Time': -12501864.1, 'Average Time': -889022.7160000005}
# Generation 11
# {'Generation': 11, 'Best Candidate': ['-fsplit-loops', '-floop-interchange', '-fipa-cp-clone'], 'Global Best Candidate': ['-fsplit-loops', '-floop-interchange', '-fipa-cp-clone'], 'Worst Candidate': ['-fsplit-paths', '-fpredictive-commoning', '-funswitch-loops', '-fversion-loops-for-strides'], 'Best Time': -14515718.0, 'Worst Time': 8061343.4, 'Global Best Time': -14515718.0, 'Average Time': -1555967.2200000002}
# Generation 12
# {'Generation': 12, 'Best Candidate': ['-ftree-partial-pre', '-fpredictive-commoning', '-funswitch-loops'], 'Global Best Candidate': ['-fsplit-loops', '-floop-interchange', '-fipa-cp-clone'], 'Worst Candidate': ['-fpredictive-commoning'], 'Best Time': -12522592.5, 'Worst Time': 7921101.6, 'Global Best Time': -14515718.0, 'Average Time': -972574.2379999998}
# Generation 13
# {'Generation': 13, 'Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-fipa-cp-clone'], 'Best Time': -16705983.1, 'Worst Time': 17945111.0, 'Global Best Time': -16705983.1, 'Average Time': -1506899.1379999996}
# Generation 14
# {'Generation': 14, 'Best Candidate': ['-fgcse-after-reload'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -9850621.8, 'Worst Time': 12189021.7, 'Global Best Time': -16705983.1, 'Average Time': -267091.0700000001}
# Generation 15
# {'Generation': 15, 'Best Candidate': ['-fgcse-after-reload', '-fsplit-loops'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-ftree-loop-distribution', '-fsplit-loops'], 'Best Time': -6586209.2, 'Worst Time': 6314156.5, 'Global Best Time': -16705983.1, 'Average Time': -826911.6460000004}
# Generation 16
# {'Generation': 16, 'Best Candidate': ['-floop-interchange'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-fgcse-after-reload', '-floop-unroll-and-jam'], 'Best Time': -8621169.4, 'Worst Time': 4695080.9, 'Global Best Time': -16705983.1, 'Average Time': -1016627.7879999998}
# Generation 17
# {'Generation': 17, 'Best Candidate': ['-fpredictive-commoning', '-fipa-cp-clone'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-ftree-partial-pre', '-ftree-loop-distribution'], 'Best Time': -9453360.9, 'Worst Time': 8353238.2, 'Global Best Time': -16705983.1, 'Average Time': -1392122.2839999995}
# Generation 18
# {'Generation': 18, 'Best Candidate': ['-fversion-loops-for-strides', '-funswitch-loops', '-fsplit-paths', '-fipa-cp-clone'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-fpeel-loops', '-fgcse-after-reload'], 'Best Time': -6857075.5, 'Worst Time': 5795624.6, 'Global Best Time': -16705983.1, 'Average Time': -1382316.8900000006}
# Generation 19
# {'Generation': 19, 'Best Candidate': ['-fpeel-loops'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-fsplit-paths', '-fgcse-after-reload'], 'Best Time': -11443978.8, 'Worst Time': 6602566.8, 'Global Best Time': -16705983.1, 'Average Time': -362288.9720000003}
# Generation 20
# {'Generation': 20, 'Best Candidate': ['-floop-interchange', '-ftree-partial-pre', '-funswitch-loops'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops', '-fvect-cost-model=dynamic', '-fgcse-after-reload', '-fpredictive-commoning'], 'Best Time': -8062402.4, 'Worst Time': 5409693.7, 'Global Best Time': -16705983.1, 'Average Time': -1142891.0099999988}
# Generation 21
# {'Generation': 21, 'Best Candidate': ['-funswitch-loops', '-fsplit-loops'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-fipa-cp-clone', '-floop-unroll-and-jam'], 'Best Time': -13029217.5, 'Worst Time': 5496986.4, 'Global Best Time': -16705983.1, 'Average Time': -1063504.114}
# Generation 22
# {'Generation': 22, 'Best Candidate': ['-fvect-cost-model=dynamic', '-fgcse-after-reload', '-fpredictive-commoning'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-fvect-cost-model=dynamic', '-fpeel-loops', '-ftree-partial-pre'], 'Best Time': -7171643.2, 'Worst Time': 7861387.3, 'Global Best Time': -16705983.1, 'Average Time': -892578.0619999999}
# Generation 23
# {'Generation': 23, 'Best Candidate': ['-floop-unroll-and-jam'], 'Global Best Candidate': ['-fsplit-paths', '-fpeel-loops'], 'Worst Candidate': ['-funswitch-loops'], 'Best Time': -8938160.9, 'Worst Time': 9005163.7, 'Global Best Time': -16705983.1, 'Average Time': -810060.1940000004}
# Generation 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[279], line 15
#      13 for source in sources:
#      14     print(f"Running GA for {source}")
# ---> 15     stats_df = run_ga(sources[0], PASS_POOL, generations=100, pop_size=50, seq_length=5)
#      16     stats_df.to_csv(f"results/{source}_stats.csv", index=False)
#
# Cell In[274], line 18, in run_ga(input_bc, pass_pool, generations, pop_size, seq_length)
#      16 fitnesses = []
#      17 for candidate in population:
# ---> 18     fitness = evaluate_candidate(candidate, input_bc, "./scratch")
#      19     fitnesses.append((fitness, candidate))
#      20     # print(f"Candidate {candidate} => Fitness {fitness}")
#      21
#      22 # Update global best candidate
#
# Cell In[271], line 67, in evaluate_candidate(pass_order, input, workdir, mode)
#      65 apply_passes(input, pass_order)
#      66 if mode == "runtime":
# ---> 67     fitness = measure_runtime(input)
#      68 elif mode == "size":
#      69     fitness = measure_size(input)
#
# Cell In[271], line 25, in measure_runtime(binary, count, mode)
#      22 cycles_line = next((line for line in lines if "cycles" in line), None)
#      23 time_line = next((line for line in lines if "seconds time elapsed" in line), None)
# ---> 25 result_base = subprocess.run(
#      26     ["perf", "stat", "-e", "cycles", f"./{binary}/{binary}_base"],
#      27     capture_output=True,
#      28     text=True,
#      29     cwd="./beebs/src"
#      30 )
#      31 # Extract cycles and time from stderr
#      32 lines_base = result_base.stderr.splitlines()
#
# File /usr/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /usr/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File /usr/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
